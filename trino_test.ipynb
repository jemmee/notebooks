# %%
# !pip install trino
# Out:
# Collecting trino
#   Downloading trino-0.336.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: lz4 in /opt/anaconda3/lib/python3.13/site-packages (from trino) (4.3.2)
# Collecting orjson>=3.11.0 (from trino)
#   Downloading orjson-3.11.5-cp313-cp313-macosx_15_0_arm64.whl.metadata (41 kB)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.13/site-packages (from trino) (2.9.0.post0)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.13/site-packages (from trino) (2025.2)
# Requirement already satisfied: requests>=2.32.4 in /opt/anaconda3/lib/python3.13/site-packages (from trino) (2.32.5)
# Collecting tzlocal (from trino)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: zstandard in /opt/anaconda3/lib/python3.13/site-packages (from trino) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.4->trino) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.4->trino) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.4->trino) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.4->trino) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil->trino) (1.17.0)
# Downloading trino-0.336.0-py3-none-any.whl (57 kB)
# Downloading orjson-3.11.5-cp313-cp313-macosx_15_0_arm64.whl (129 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: tzlocal, orjson, trino
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [trino]
# Successfully installed orjson-3.11.5 trino-0.336.0 tzlocal-5.3.1

# %%
# docker run -d \
#  --name trino \
#  -p 8080:8080 \
#  trinodb/trino

from trino.dbapi import connect

# 1. Setup the connection
# Note: 'user' is required by Trino but can be any string for this demo
conn = connect(
    host="localhost",
    port=8080,
    user="admin",
    catalog="tpch",
    schema="tiny",
)

# 2. Create a cursor to execute queries
cur = conn.cursor()

print("--- Querying Top 5 Nations by Region ---")
query = """
    SELECT n.name, r.name as region 
    FROM nation n 
    JOIN region r ON n.regionkey = r.regionkey 
    LIMIT 5
"""

try:
    # 3. Execute the query
    cur.execute(query)
    
    # 4. Fetch and print results
    rows = cur.fetchall()
    for row in rows:
        print(f"Nation: {row[0]:<15} | Region: {row[1]}")

except Exception as e:
    print(f"Error: {e}")

finally:
    # 5. Always close your connections
    cur.close()
    conn.close()
# Out:
# --- Querying Top 5 Nations by Region ---
# Nation: ALGERIA         | Region: AFRICA
# Nation: ARGENTINA       | Region: AMERICA
# Nation: BRAZIL          | Region: AMERICA
# Nation: CANADA          | Region: AMERICA
# Nation: EGYPT           | Region: MIDDLE EAST
