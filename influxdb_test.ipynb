# %%
# !pip install influxdb-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.3/746.3 kB 11.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [influxdb-client]1/2 [influxdb-client]
# ...

# %%
# docker run -d --name influxdb -p 8086:8086 \
#  -e DOCKER_INFLUXDB_INIT_MODE=setup \
#  -e DOCKER_INFLUXDB_INIT_USERNAME=admin \
#  -e DOCKER_INFLUXDB_INIT_PASSWORD=password123 \
#  -e DOCKER_INFLUXDB_INIT_ORG=my-org \
#  -e DOCKER_INFLUXDB_INIT_BUCKET=sensors \
#  influxdb:latest

import time
from influxdb_client import InfluxDBClient, Point
from influxdb_client.client.write_api import SYNCHRONOUS

# 1. Setup Connection
token = "siA8gw9PC68idXWydtwrqjGHzykU2kUY2N12gLVj0fgNGiSpswGjRVaViTzZ_1GEPRURWTqtAsslrGMq_17YoQ==" # Get this from http://localhost:8086 or docker exec influxdb influx auth list
org = "my-org"
bucket = "sensors"

with InfluxDBClient(url="http://localhost:8086", token=token, org=org) as client:
    write_api = client.write_api(write_options=SYNCHRONOUS)
    
    # 2. Record a time-stamped point
    # measurement = table, tag = indexed metadata, field = value
    point = Point("environment") \
        .tag("location", "office") \
        .field("temperature", 23.5)
    
    write_api.write(bucket=bucket, record=point)
    print("Point recorded!")
# Out:
# Point recorded!
