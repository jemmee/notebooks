# %%
import time
from watchdog.observers.polling import PollingObserver as Observer
from watchdog.events import LoggingEventHandler

# Use PollingObserver instead of the default Observer
observer = Observer(timeout=0.1) 
observer.schedule(LoggingEventHandler(), path='.', recursive=True)
observer.start()

try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    observer.stop()
observer.join()
# Out:
# File /Users/jemmeeyung/projects/notebooks/echo_test.py was modified!
# File /Users/jemmeeyung/projects/notebooks/watchdog_test.ipynb was modified!
# File /Users/jemmeeyung/projects/notebooks was modified!
# File /Users/jemmeeyung/projects/notebooks/.~watchdog_test.ipynb was modified!
# File /Users/jemmeeyung/projects/notebooks was modified!
# File /Users/jemmeeyung/projects/notebooks/wallet_test.py was modified!
# File /Users/jemmeeyung/projects/notebooks/wallet.py was modified!
# File /Users/jemmeeyung/projects/notebooks/watchdog_test.ipynb was modified!
# File /Users/jemmeeyung/projects/notebooks was modified!
# File /Users/jemmeeyung/projects/notebooks/.~watchdog_test.ipynb was modified!
# File /Users/jemmeeyung/projects/notebooks was modified!
# File /Users/jemmeeyung/projects/notebooks/.ipynb_checkpoints/watchdog_test-checkpoint.ipynb was modified!
