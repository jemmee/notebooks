# %%
# !pip install fpdf2

# %%
from fpdf import FPDF

# Create a new PDF object
pdf = FPDF()

# Add a page
pdf.add_page()

# Set the font (e.g., Arial, size 12)
pdf.set_font("Arial", size=12)

# Add text to the PDF
# cell(width, height, text, border, next_line, align)
pdf.cell(200, 10, txt="Hello, this is a PDF generated with Python!", ln=True, align='C')

# Add another line of text
pdf.cell(200, 10, txt="This is a second line of text.", ln=True, align='L')

# Save the PDF to a file
pdf.output("fpdf2_test.pdf")

print("PDF generated successfully!")
# Out:
# PDF generated successfully!
# /var/folders/hg/qd18ch2926g6xmmp0vk0lpzm0000gn/T/ipykernel_44884/1811642525.py:10: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font("Arial", size=12)
# /var/folders/hg/qd18ch2926g6xmmp0vk0lpzm0000gn/T/ipykernel_44884/1811642525.py:14: DeprecationWarning: The parameter "txt" has been renamed to "text" in 2.7.6
#   pdf.cell(200, 10, txt="Hello, this is a PDF generated with Python!", ln=True, align='C')
# /var/folders/hg/qd18ch2926g6xmmp0vk0lpzm0000gn/T/ipykernel_44884/1811642525.py:14: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(200, 10, txt="Hello, this is a PDF generated with Python!", ln=True, align='C')
# /var/folders/hg/qd18ch2926g6xmmp0vk0lpzm0000gn/T/ipykernel_44884/1811642525.py:17: DeprecationWarning: The parameter "txt" has been renamed to "text" in 2.7.6
# ...
